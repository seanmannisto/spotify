# %%
# !pip install spotipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spotipy in /usr/local/lib/python3.9/dist-packages (2.22.1)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.9/dist-packages (from spotipy) (2.25.1)
# Requirement already satisfied: redis>=3.5.3 in /usr/local/lib/python3.9/dist-packages (from spotipy) (4.5.1)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spotipy) (1.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.9/dist-packages (from spotipy) (1.26.14)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.9/dist-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests>=2.25.0->spotipy) (4.0.0)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Set up Spotify API credentials
client_id = 'f6a2cc12d09d45c78e24356d0348ba0b'
client_secret = 'fcac6403f263466f8fb344651b7cd75d'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Define function to get audio features for a song
def get_audio_features(track_id):
    audio_features = sp.audio_features(tracks=[track_id])[0]
    return audio_features

# Define function to get all tracks from a playlist
def get_playlist_tracks(username, playlist_id):
    # Get playlist details
    playlist = sp.user_playlist(username, playlist_id)
    # Extract playlist name
    playlist_name = playlist['name']
    # Get playlist tracks
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks, playlist_name

# %%
# Get all tracks from the playlist
username = 'spotify'
playlist_id = '37i9dQZF1DX4o1oenSJRJd'
#playlist_id = '1yG9WLgaK7JgRKCzd1Llvw'
tracks, playlist_name = get_playlist_tracks(username, playlist_id)

# Extract audio features for each track and store in a dataframe
audio_features = []
for track in tracks:
    audio_features.append(get_audio_features(track['track']['id']))
df = pd.DataFrame(audio_features)

# Add track name and artists to the dataframe
track_names = []
artists = []
for track in tracks:
    track_names.append(track['track']['name'])
    artist_names = []
    for artist in track['track']['artists']:
        artist_names.append(artist['name'])
    artists.append(artist_names)
df['name'] = track_names
df['artists'] = artists

# %%
#df.sample(10)

# %%
# Select the features to use for clustering and PCA
features = ['danceability', 'energy', 'speechiness', 'acousticness', 'liveness', 'valence', 'tempo', 'loudness']
#features = ['energy', 'acousticness', 'valence']
# Normalize the features
scaler = StandardScaler()
dfn=df
dfn[features] = scaler.fit_transform(df[features])

# %%
# Determine the optimal number of clusters using the silhouette score

silhouette_scores = []
for k in range(2, 25):
    kmeans = KMeans(n_clusters=k, random_state=1)
    preds = kmeans.fit_predict(df[features])
    score = silhouette_score(df[features], preds)
    silhouette_scores.append(score)
    
optimal_k = silhouette_scores.index(max(silhouette_scores)) + 2

# Fit the data into KMeans with the optimal number of clusters
kmeans = KMeans(n_clusters=optimal_k)
df['cluster'] = kmeans.fit_predict(dfn[features])

# %%
# Reduce the selected features into three dimensions using PCA
pca = PCA(n_components=3)
df_pca = pca.fit_transform(dfn[features])
df_pca = pd.DataFrame(df_pca, columns=['PC1', 'PC2', 'PC3'])

# Combine the cluster labels and PCA results into one dataframe
df_plot = pd.concat([dfn, df_pca], axis=1)

# %%
# Plot a 3D scatter plot using plotly express
fig = px.scatter_3d(df_plot, x='energy', y='acousticness', z='valence', color='cluster', hover_data=['name', 'artists'] + features,
                    )
# adjust the size of the figure and add title
fig.update_layout(
    width=1200, 
    height=1000,
    title={
        'text': f"3D Scatter Plot for Playlist: {playlist_name}",
        'x': 0.5,
        'y': 0.95,
        'xanchor': 'center',
        'yanchor': 'top'
    }
)



# show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="41ed3839-3f66-47de-a714-1ddef6509034" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41ed3839-3f66-47de-a714-1ddef6509034")) {                    Plotly.newPlot(                        "41ed3839-3f66-47de-a714-1ddef6509034",                        [{"customdata":[["Umbrella",["Rihanna","JAY-Z"],-0.5170027466219244,0.5982090856784464,-0.9467503484246197,2.134854646179728,0.3284052762004174],["In Da Club",["50 Cent"],1.431223858029129,3.2520247323635836,-0.6939559213520451,-1.1591485758554403,1.2692908214230358],["Just Dance",["Lady Gaga","Colby O'Donis"],0.9426403835084884,-0.6838455154666272,0.13643072609068488,-0.024141665886957164,0.360334615994507],["I'm Like A Bird",["Nelly Furtado"],-0.2727110093616041,-0.6315167562362161,0.49644755721571393,-1.1750362404093144,0.06576070692645128],["Hips Don't Lie (feat. Wyclef Jean)",["Shakira","Wyclef Jean"],0.6739194725221367,-0.19046007129417905,1.8895561646125654,-0.7682335702274053,-0.33541599790574345],["Yeah! (feat. Lil Jon & Ludacris)",["Usher","Lil Jon","Ludacris"],1.382365510577065,0.3241060611381974,-0.9764908692566873,-0.5723249361976607,0.27896629845472964],["Family Affair",["Mary J. Blige"],1.4861894989127011,-0.5119081637095619,-0.6047343588558421,-1.0482095255878956,0.767691193044913],["Lose Yourself - From \"8 Mile\" Soundtrack",["Eminem"],0.14869223741244783,2.130694177426202,1.529539333487536,2.030741407350144,0.3479748715580851],["Crazy",["Gnarls Barkley"],1.0220351981180924,-0.6489596759796864,-0.6336922344028553,-0.29988091069974804,1.8702833946440516],["Empire State Of Mind",["JAY-Z","Alicia Keys"],-1.0788737423206605,3.8126900098322754,2.320011071392491,2.1174762871738864,1.9068476386017996],["This Love",["Maroon 5"],0.270838106042608,-0.6003686852657332,-0.5522971247571966,-0.9633183994284307,0.323770372036759],["Yellow",["Coldplay"],-1.4575259350741567,-0.7212232006312066,0.5512327271695227,2.1091205524825902,-1.0229267821817127],["In the End",["Linkin Park"],-0.6818996692726399,-0.34370858046895464,0.35557140590591985,-0.567421336026712,-0.32408623217235655],["Without Me",["Eminem"],1.4678676186181772,-0.15183646329078027,0.5747120857211548,-0.28909299032366054,1.2430263644956392],["Mr. Brightside",["The Killers"],-1.927787529300273,-0.1406231577414065,-0.5014251812286599,1.115101954629225,0.005506952798894434],["Seven Nation Army",["The White Stripes"],0.4601642024193563,-0.22036221942584258,1.357357370775566,0.1564677356094274,-1.3216206060619091],["Feel Good Inc.",["Gorillaz"],0.9182112097824564,1.133955906370751,3.5174583575257397,0.7434482904726771,-0.7407126175500788],["Viva La Vida",["Coldplay"],-1.1094102094782006,-0.7137476635982907,-0.4270738791484909,0.7221078225287078,-0.9652479748117435],["Numb",["Linkin Park"],-1.0483372751631204,-0.5966309167492753,3.7209461316398866,-0.3761809293597104,0.5601504843833285],["Promiscuous",["Nelly Furtado","Timbaland"],0.857138275467377,-0.4408905618968611,-0.07488350087400603,-0.20710479546539723,-0.44150380431836467],["Pumped Up Kicks",["Foster The People"],0.3990912681042762,-0.707518049404194,-0.5319483473457819,0.3282506567981039,-0.31327145579048743],["The Real Slim Shady",["Eminem"],1.7182666493100047,-0.3586596545347864,-0.9248362804430962,-0.5924885401006018,0.5132864533952286],["Bad Romance",["Lady Gaga"],0.17312141113847987,-0.6190575278480229,-0.6211699098419848,-0.02378860667464884,0.7651162462873251],["Don't Stop The Music",["Rihanna"],1.0220351981180924,-0.2701991329786152,-0.861442012353689,0.12006340794030394,-0.17576929893529342],["Run This Town",["JAY-Z","Rihanna","Kanye West"],-0.21774536847803203,2.541848714236575,0.7781998598353018,-1.2852691722522425,1.7708904498011586],["The Way I Are",["Timbala ...

# %%
# Export the plot as an interactive HTML file
pio.write_html(fig, file='spotify_clusters.html', auto_open=True)

# %%
# Plot a 3D scatter plot using plotly express
fig = px.scatter_3d(df_plot, x='PC1', y='PC2', z='PC3', color='cluster', hover_data=['name', 'artists'] + features,
                    )

#color_continuous_scale='RdYlBu'



# adjust the size of the figure
fig.update_layout(width=1200, height=1000)

# show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cf3f2ded-ce03-443a-b31a-3f2e585faa85" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf3f2ded-ce03-443a-b31a-3f2e585faa85")) {                    Plotly.newPlot(                        "cf3f2ded-ce03-443a-b31a-3f2e585faa85",                        [{"customdata":[["Umbrella",["Rihanna","JAY-Z"],-0.5170027466219244,0.5967362943673039,0.5982090856784464,-0.6643023515285132,-0.9467503484246197,-0.006359700141506733,2.134854646179728,0.3284052762004174],["In Da Club",["50 Cent"],1.431223858029129,-0.14781791907175454,3.2520247323635836,0.7796718539772003,-0.6939559213520451,1.0080168827617544,-1.1591485758554403,1.2692908214230358],["Just Dance",["Lady Gaga","Colby O'Donis"],0.9426403835084884,-0.01803323966494605,-0.6838455154666272,-0.562277439490872,0.13643072609068488,0.7433969046130774,-0.024141665886957164,0.360334615994507],["I'm Like A Bird",["Nelly Furtado"],-0.2727110093616041,-0.9196952229122464,-0.6315167562362161,0.1305268618458125,0.49644755721571393,0.16564328565513325,-1.1750362404093144,0.06576070692645128],["Hips Don't Lie (feat. Wyclef Jean)",["Shakira","Wyclef Jean"],0.6739194725221367,0.5625824313655122,-0.19046007129417905,0.9175433567307691,1.8895561646125654,0.8007312332119574,-0.7682335702274053,-0.33541599790574345],["Yeah! (feat. Lil Jon & Ludacris)",["Usher","Lil Jon","Ludacris"],1.382365510577065,0.33716693555368765,0.3241060611381974,-0.6088090716702017,-0.9764908692566873,0.028922963611650192,-0.5723249361976607,0.27896629845472964],["Family Affair",["Mary J. Blige"],1.4861894989127011,-1.302218488532313,-0.5119081637095619,0.04435717262483188,-0.6047343588558421,1.7313114897014703,-1.0482095255878956,0.767691193044913],["Lose Yourself - From \"8 Mile\" Soundtrack",["Eminem"],0.14869223741244783,0.01612062333684566,2.130694177426202,-0.6640725656905907,1.529539333487536,-2.272388779688008,2.030741407350144,0.3479748715580851],["Crazy",["Gnarls Barkley"],1.0220351981180924,-0.0043716944642293665,-0.6489596759796864,-0.6151281822130736,-0.6336922344028553,0.15682261971684403,-0.29988091069974804,1.8702833946440516],["Empire State Of Mind",["JAY-Z","Alicia Keys"],-1.0788737423206605,1.4642444146128124,3.8126900098322754,-0.5444690370518694,2.320011071392491,1.034478880576622,2.1174762871738864,1.9068476386017996],["This Love",["Maroon 5"],0.270838106042608,0.8221517901791292,-0.6003686852657332,-0.4123421802463658,-0.5522971247571966,1.0256582146383328,-0.9633183994284307,0.323770372036759],["Yellow",["Coldplay"],-1.4575259350741567,-0.550833502492896,-0.7212232006312066,-0.7002063887039218,0.5512327271695227,-1.285356261193444,2.1091205524825902,-1.0229267821817127],["In the End",["Linkin Park"],-0.6818996692726399,0.8358133353798459,-0.34370858046895464,-0.6589023843373317,0.35557140590591985,-0.7781679697418135,-0.567421336026712,-0.32408623217235655],["Without Me",["Eminem"],1.4678676186181772,-0.49618732169002927,-0.15183646329078027,-0.6975064051083312,0.5747120857211548,0.3773392681740748,-0.28909299032366054,1.2430263644956392],["Mr. Brightside",["The Killers"],-1.927787529300273,1.156859647596688,-0.1406231577414065,-0.706985070922639,-0.5014251812286599,-1.50146257668153,1.115101954629225,0.005506952798894434],["Seven Nation Army",["The White Stripes"],0.4601642024193563,-2.0194496115699385,-0.22036221942584258,-0.6915319733223432,1.357357370775566,-1.3162285919774561,0.1564677356094274,-1.3216206060619091],["Feel Good Inc.",["Gorillaz"],0.9182112097824564,-0.25027950807712973,1.133955906370751,-0.6659108523939715,3.5174583575257397,0.862475894779982,0.7434482904726771,-0.7407126175500788],["Viva La Vida",["Coldplay"],-1.1094102094782006,-0.851387496908663,-0.7137476635982907,-0.165896869074361,-0. ...

# %%
fig.update_traces(hovertemplate="<br>".join([
    "Name: %{customdata[0]}",
    "Artists: %{customdata[1]}",
    "Danceability: %{customdata[2]:.3f}",
    "Energy: %{customdata[3]:.3f}",
    "Speechiness: %{customdata[4]:.3f}",
    "Acousticness: %{customdata[5]:.3f}",
    "Instrumentalness: %{customdata[6]:.3f}",
    "Liveness: %{customdata[7]:.3f}",
    "Valence: %{customdata[8]:.3f}"
]))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="08838aa0-2bf3-4ca7-835d-64f8cca3dbe5" class="plotly-graph-div" style="height:1000px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08838aa0-2bf3-4ca7-835d-64f8cca3dbe5")) {                    Plotly.newPlot(                        "08838aa0-2bf3-4ca7-835d-64f8cca3dbe5",                        [{"customdata":[["Umbrella",["Rihanna","JAY-Z"],-0.5170027466219244,0.5967362943673039,0.5982090856784464,-0.6643023515285132,-0.9467503484246197,-0.006359700141506733,2.134854646179728,0.3284052762004174],["In Da Club",["50 Cent"],1.431223858029129,-0.14781791907175454,3.2520247323635836,0.7796718539772003,-0.6939559213520451,1.0080168827617544,-1.1591485758554403,1.2692908214230358],["Just Dance",["Lady Gaga","Colby O'Donis"],0.9426403835084884,-0.01803323966494605,-0.6838455154666272,-0.562277439490872,0.13643072609068488,0.7433969046130774,-0.024141665886957164,0.360334615994507],["I'm Like A Bird",["Nelly Furtado"],-0.2727110093616041,-0.9196952229122464,-0.6315167562362161,0.1305268618458125,0.49644755721571393,0.16564328565513325,-1.1750362404093144,0.06576070692645128],["Hips Don't Lie (feat. Wyclef Jean)",["Shakira","Wyclef Jean"],0.6739194725221367,0.5625824313655122,-0.19046007129417905,0.9175433567307691,1.8895561646125654,0.8007312332119574,-0.7682335702274053,-0.33541599790574345],["Yeah! (feat. Lil Jon & Ludacris)",["Usher","Lil Jon","Ludacris"],1.382365510577065,0.33716693555368765,0.3241060611381974,-0.6088090716702017,-0.9764908692566873,0.028922963611650192,-0.5723249361976607,0.27896629845472964],["Family Affair",["Mary J. Blige"],1.4861894989127011,-1.302218488532313,-0.5119081637095619,0.04435717262483188,-0.6047343588558421,1.7313114897014703,-1.0482095255878956,0.767691193044913],["Lose Yourself - From \"8 Mile\" Soundtrack",["Eminem"],0.14869223741244783,0.01612062333684566,2.130694177426202,-0.6640725656905907,1.529539333487536,-2.272388779688008,2.030741407350144,0.3479748715580851],["Crazy",["Gnarls Barkley"],1.0220351981180924,-0.0043716944642293665,-0.6489596759796864,-0.6151281822130736,-0.6336922344028553,0.15682261971684403,-0.29988091069974804,1.8702833946440516],["Empire State Of Mind",["JAY-Z","Alicia Keys"],-1.0788737423206605,1.4642444146128124,3.8126900098322754,-0.5444690370518694,2.320011071392491,1.034478880576622,2.1174762871738864,1.9068476386017996],["This Love",["Maroon 5"],0.270838106042608,0.8221517901791292,-0.6003686852657332,-0.4123421802463658,-0.5522971247571966,1.0256582146383328,-0.9633183994284307,0.323770372036759],["Yellow",["Coldplay"],-1.4575259350741567,-0.550833502492896,-0.7212232006312066,-0.7002063887039218,0.5512327271695227,-1.285356261193444,2.1091205524825902,-1.0229267821817127],["In the End",["Linkin Park"],-0.6818996692726399,0.8358133353798459,-0.34370858046895464,-0.6589023843373317,0.35557140590591985,-0.7781679697418135,-0.567421336026712,-0.32408623217235655],["Without Me",["Eminem"],1.4678676186181772,-0.49618732169002927,-0.15183646329078027,-0.6975064051083312,0.5747120857211548,0.3773392681740748,-0.28909299032366054,1.2430263644956392],["Mr. Brightside",["The Killers"],-1.927787529300273,1.156859647596688,-0.1406231577414065,-0.706985070922639,-0.5014251812286599,-1.50146257668153,1.115101954629225,0.005506952798894434],["Seven Nation Army",["The White Stripes"],0.4601642024193563,-2.0194496115699385,-0.22036221942584258,-0.6915319733223432,1.357357370775566,-1.3162285919774561,0.1564677356094274,-1.3216206060619091],["Feel Good Inc.",["Gorillaz"],0.9182112097824564,-0.25027950807712973,1.133955906370751,-0.6659108523939715,3.5174583575257397,0.862475894779982,0.7434482904726771,-0.7407126175500788],["Viva La Vida",["Coldplay"],-1.1094102094782006,-0.851387496908663,-0.7137476635982907,-0.165896869074361,-0. ...

# %%
# Export the plot as an interactive HTML file
pio.write_html(fig, file='spotify_PCA.html', auto_open=True)

# %%
# Group songs by cluster and print the results
grouped_df = df.groupby('cluster')
for name, group in grouped_df:
    print(f"Cluster {name+1}:")
    for index, row in group.iterrows():
        print(f"- {row['name']} by {', '.join(row['artists'])}")
    print()
# Out:
# Cluster 1:
# - Seven Nation Army by The White Stripes
# - Viva La Vida by Coldplay
# - The Scientist by Coldplay
# - Fix You by Coldplay
# - Pon de Replay by Rihanna
# - Clocks by Coldplay
# - Chasing Cars by Snow Patrol
# - If I Ain't Got You by Alicia Keys
# - Back To Black by Amy Winehouse
# - She Will Be Loved - Radio Mix by Maroon 5
# - Take Me Out by Franz Ferdinand
# - Hey There Delilah by Plain White T's
# - Alors on danse - Radio Edit by Stromae
# - Dilemma by Nelly, Kelly Rowland
# - My Boo by Usher, Alicia Keys
# - Grenade by Bruno Mars
# - So Sick by Ne-Yo
# - I Knew You Were Trouble. by Taylor Swift
# - Put Your Records On by Corinne Bailey Rae
# - Miss Independent by Ne-Yo
# - Don't Know Why by Norah Jones
# - Here Without You by 3 Doors Down
# - Hung Up by Madonna
# - You're Beautiful by James Blunt
# - I Miss You by blink-182
# - Halo by Beyoncé
# - Bleeding Love by Leona Lewis
# - Valerie - Live At BBC Radio 1 Live Lounge, London / 2007 by Amy Winehouse
#
# Cluster 2:
# - Umbrella by Rihanna, JAY-Z
# - Lose Yourself - From "8 Mile" Soundtrack by Eminem
# - Yellow by Coldplay
# - In the End by Linkin Park
# - Mr. Brightside by The Killers
# - Rude Boy by Rihanna
# - Bring Me To Life by Evanescence
# - Till I Collapse by Eminem, Nate Dogg
# - The Reason by Hoobastank
# - Sex on Fire by Kings of Leon
# - How You Remind Me by Nickelback
# - How to Save a Life by The Fray
# - The Pretender by Foo Fighters
# - Thnks fr th Mmrs by Fall Out Boy
# - Fireflies by Owl City
# - All The Things She Said by t.A.T.u.
# - Sugar, We're Goin Down by Fall Out Boy
# - Forever by Chris Brown
# - Welcome to the Black Parade by My Chemical Romance
# - So What by P!nk
# - Kids by MGMT
# - Dance, Dance by Fall Out Boy
# - Boulevard of Broken Dreams by Green Day
# - Live Your Life by T.I., Rihanna
# - Use Somebody by Kings of Leon
# - When You Were Young by The Killers
# - Sk8er Boi by Avril Lavigne
# - Womanizer by Britney Spears
# - Wake Me up When September Ends by Green Day
# - Somewhere Only We Know by Keane
# - Uprising by Muse
# - Best of You by Foo Fighters
# - Break Your Heart by Taio Cruz
# - Marry You by Bruno Mars
# - By the Way by Red Hot Chili Peppers
# - Bad Day by Daniel Powter
# - Wherever You Will Go by The Calling
# - Human by The Killers
# - Girlfriend by Avril Lavigne
#
# Cluster 3:
# - In Da Club by 50 Cent
# - Just Dance by Lady Gaga, Colby O'Donis
# - I'm Like A Bird by Nelly Furtado
# - Yeah! (feat. Lil Jon & Ludacris) by Usher, Lil Jon, Ludacris
# - Family Affair by Mary J. Blige
# - Crazy by Gnarls Barkley
# - This Love by Maroon 5
# - Without Me by Eminem
# - Promiscuous by Nelly Furtado, Timbaland
# - Pumped Up Kicks by Foster The People
# - The Real Slim Shady by Eminem
# - Bad Romance by Lady Gaga
# - Don't Stop The Music by Rihanna
# - Hey, Soul Sister by Train
# - Ms. Jackson by Outkast
# - Hate It Or Love It by The Game, 50 Cent
# - Can't Stop by Red Hot Chili Peppers
# - Whenever, Wherever by Shakira
# - Hey Ya! by Outkast
# - Smack That by Akon, Eminem
# - Gasolina by Daddy Yankee
# - Low (feat. T-Pain) by Flo Rida, T-Pain
# - The Next Episode by Dr. Dre, Snoop Dogg
# - Last Resort by Papa Roach
# - Alright by Kendrick Lamar
# - Say It Right by Nelly Furtado
# - Dynamite by Taio Cruz
# - Disturbia by Rihanna
# - Maneater by Nelly Furtado
# - The Middle by Jimmy Eat World
# - Where Is The Love? by Black Eyed Peas
# - Give It To Me by Timbaland, Justin Timberlake, Nelly Furtado
# - Forgot About Dre by Dr. Dre, Eminem
# - Gimme More by Britney Spears
# - Walking On A Dream by Empire of the Sun
# - Temperature by Sean Paul
# - Crazy In Love (feat. Jay-Z) by Beyoncé, JAY-Z
# - It Wasn't Me by Shaggy, Rik Rok
# - SexyBack (feat. Timbaland) by Justin Timberlake, Timbaland
# - Raise Your Glass by P!nk
# - Beautiful Girls by Sean Kingston
# - Down by Jay Sean, Lil Wayne
# - La Tortura (feat. Alejandro Sanz) by Shakira, Alejandro Sanz
# - American Boy by Estelle, Kanye West
# - Poker Face by Lady Gaga
# - Kiss Me Thru The Phone by Soulja Boy, Sammie
# - Say My Name by Destiny's Child
# - Lady - Hear Me Tonight by Modjo
# - Party In The U.S.A. by Miley Cyrus
# - Rock Your Body by Justin Timberlake
# - Drop It Like It's Hot by Snoop Dogg, Pharrell Williams
# - Unwritten by Natasha Bedingfield
# - Hot In Herre by Nelly
# - Angel by Shaggy, Rayvon
# - Ride Wit Me by Nelly, City Spud
# - Young Folks by Peter Bjorn and John
# - We Are Never Ever Getting Back Together by Taylor Swift
# - Get Busy by Sean Paul
# - Right Round by Flo Rida
# - Can't Get You out of My Head by Kylie Minogue
# - Let Me Blow Ya Mind by Eve, Gwen Stefani
# - This Is The Life by Amy Macdonald
# - King Kunta by Kendrick Lamar
# - Circus by Britney Spears
# - Teenage Dirtbag by Wheatus
#
# Cluster 4:
# - Hips Don't Lie (feat. Wyclef Jean) by Shakira, Wyclef Jean
# - Empire State Of Mind by JAY-Z, Alicia Keys
# - Feel Good Inc. by Gorillaz
# - Numb by Linkin Park
# - Run This Town by JAY-Z, Rihanna, Kanye West
# - The Way I Are by Timbaland, Keri Hilson, D.O.E.
# - Stan by Eminem, Dido
# - TiK ToK by Kesha
# - Candy Shop by 50 Cent, Olivia
# - Complicated by Avril Lavigne
# - Oops!...I Did It Again by Britney Spears
# - Dancing in the Moonlight by Toploader
# - Dani California by Red Hot Chili Peppers
# - Electric Feel by MGMT
# - Savior by Rise Against
# - Cooler Than Me - Single Mix by Mike Posner, Gigamesh
# - Last Friday Night (T.G.I.F.) by Katy Perry
# - L'Amour Toujours by Gigi D'Agostino

# %%
# Use elbow method to determine the optimal number of clusters
#wcss = []
#for i in range(1, 26):
#    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
#    kmeans.fit(df[features])
#    wcss.append(kmeans.inertia_)
#plt.plot(range(1, 26), wcss)
#plt.title('Elbow Method')
#plt.xlabel('Number of clusters')
#plt.ylabel('WCSS')
#plt.show()
